# %%
import pandas as pd

# %%
csv = pd.read_csv("ExperimentalDesign.csv", sep=";")
csv
# Out:
#                                              FileName       Condition  Biorep  \
# 0                Experiment 1_extH2O2_c-YAP_0 mM H2O2   Control-c-YAP       1
# 1                Experiment 1_extH2O2_c-YAP_1 mM H2O2      H2O2-c-YAP       1
# 2               Experiment 1_extH2O2_mt-YAP_0 mM H2O2  Control-mt-YAP       1
# 3               Experiment 1_extH2O2_mt-YAP_1 mM H2O2     H2O2-mt-YAP       1
# 4               Experiment 1_extH2O2_po-YAP_0 mM H2O2  Control-po-YAP       1
# 5               Experiment 1_extH2O2_po-YAP_1 mM H2O2     H2O2-po-YAP       1
# 6   Experiment 4_extH2O2_c-YAP_concentration curve...   Control-c-YAP       2
# 7   Experiment 4_extH2O2_c-YAP_concentration curve...      H2O2-c1000       1
# 8   Experiment 4_extH2O2_c-YAP_concentration curve...       H2O2-c100       1
# 9   Experiment 4_extH2O2_c-YAP_concentration curve...        H2O2-c10       1
# 10  Experiment 4_extH2O2_c-YAP_concentration curve...       H2O2-c300       1
# ...

# %%
csv.to_csv("ExperimentalDesign.tsv", sep="\t")
