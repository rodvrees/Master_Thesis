# %%
import pandas as pd

# %%
csv = pd.read_csv("ExperimentalDesign.csv", sep=";")
csv
# Out:
#                         FileName  Condition  Biorep  Fraction  Techrep
# 0    1DLC0080815QE_RRAG_001_rep1          1       1         1        1
# 1    1DLC0080815QE_RRAG_001_rep2          1       1         1        2
# 2     1DLC120314QE_RRAG_001_rep1          1       1         1        3
# 3     1DLC120314QE_RRAG_001_rep2          1       1         1        4
# 4    1DLC012615QE_RRAG_001B_rep1          1       2         1        1
# ..                           ...        ...     ...       ...      ...
# 484   1DLC123114QE_RRAG_064_rep4         64       1         1        4
# 485  1DLC071515QE_RRAG_064B_rep1         64       2         1        1
# 486  1DLC071515QE_RRAG_064B_rep2         64       2         1        2
# 487  1DLC071515QE_RRAG_064B_rep3         64       2         1        3
# 488  1DLC071515QE_RRAG_064B_rep4         64       2         1        4
#
# [489 rows x 5 columns]

# %%
csv.to_csv("ExperimentalDesign.tsv", sep="\t")
