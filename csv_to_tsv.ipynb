# %%
import pandas as pd

# %%
csv = pd.read_csv("ExperimentalDesign.csv", sep=";")
csv
# Out:
#                                              Filename Condition  Biorep  \
# 0   20180618_QX0_JaBa_SA_LC12_5_CSF1_1_8-1xD1xS1fM...        AD       1
# 1   20180618_QX0_JaBa_SA_LC12_5_CSF1_1_8-1xD1xS1fM...   Control       1
# 2   20180618_QX0_JaBa_SA_LC12_5_CSF1_1_8-1xD1xS1fM...        AD       1
# 3   20180618_QX0_JaBa_SA_LC12_5_CSF1_1_8-1xD1xS1fM...   Control       1
# 4   20180618_QX0_JaBa_SA_LC12_5_CSF1_1_8-1xD1xS1fM...        AD       1
# 5   20180618_QX0_JaBa_SA_LC12_5_CSF1_1_8-1xD1xS1fM...   Control       1
# 6   20180618_QX0_JaBa_SA_LC12_5_CSF1_1_8-1xD1xS1fM...        AD       1
# 7   20180618_QX0_JaBa_SA_LC12_5_CSF1_1_8-1xD1xS1fM...   Control       1
# 8   20180618_QX0_JaBa_SA_LC12_5_CSF1_1_8-1xD1xS1fM...        AD       1
# 9   20180618_QX0_JaBa_SA_LC12_5_CSF1_1_8-1xD1xS1fM...   Control       1
# 10  20180618_QX0_JaBa_SA_LC12_5_CSF1_1_8-1xD1xS1fM...        AD       1
# 11  20180618_QX0_JaBa_SA_LC12_5_CSF1_1_8-1xD1xS1fM...   Control       1
# ...

# %%
csv.to_csv("ExperimentalDesign.tsv", sep="\t")
