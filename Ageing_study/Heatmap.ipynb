# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
matrix = pd.read_csv("matrix_normalized.tsv", sep="\t", index_col="Modification")
annot = pd.read_csv("data_v2.csv")
# Out:
# /tmp/ipykernel_4028630/4004183442.py:2: DtypeWarning: Columns (22) have mixed types. Specify dtype option on import or set low_memory=False.
#   annot = pd.read_csv("data_v2.csv")

# %%
matrix
# Out:
#                                       006       011       014       024  \
# Modification
# Ala->Arg[A]                      0.376701  0.000000  0.515132  0.000000
# Ala->Asn[A]                      0.433723  0.466306  0.484282  0.602464
# Ala->Asp[A]                      0.732569  0.693614  0.763762  1.000000
# Ala->Cys[A]                      0.560446  0.642206  0.969317  0.888385
# Ala->Gln[A]                      1.000000  0.616939  0.628822  0.805827
# ...                                   ...       ...       ...       ...
# [999996]GIST-Quat_2H(9)[N-TERM]  0.580700  0.000000  0.000000  0.000000
# [999998]Galactosyl[N-TERM]       0.198217  0.000000  0.000000  0.000000
# [999999]Galactosyl[K]            0.000000  0.000000  0.000000  0.000000
# [99999]ICPL_2H(4)[N-TERM]        0.000000  0.000000  0.000000  0.000000
# semi_tryptic                     0.975136  0.916835  0.854140  0.871341
#
#                                       025       028     C1077     C1093  \
# Modification
# ...

# %%
sns.clustermap(data=matrix, yticklabels=False, cmap="vlag")
# Out:
# /home/robbe/.local/lib/python3.9/site-packages/seaborn/matrix.py:654: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)
