# %%
import pandas as pd
import os
from pathlib import Path
import re

# %%
dir = "/home/robbe/ionbot/PXD010138/ionbot_files"

dirlist = [x[0] for x in os.walk(dir)]
dirlist = dirlist[1:]
print(dirlist)
# Out:
# ['/home/robbe/ionbot/PXD010138/ionbot_files/161007_A297-3_R3', '/home/robbe/ionbot/PXD010138/ionbot_files/161206_W15_R3', '/home/robbe/ionbot/PXD010138/ionbot_files/170416_C613_R3', '/home/robbe/ionbot/PXD010138/ionbot_files/160922_BR206-3_R2', '/home/robbe/ionbot/PXD010138/ionbot_files/161206_B432_R2', '/home/robbe/ionbot/PXD010138/ionbot_files/161013_Bl656_FASP2_R3', '/home/robbe/ionbot/PXD010138/ionbot_files/161206_B355_R3', '/home/robbe/ionbot/PXD010138/ionbot_files/170317_A177_R3', '/home/robbe/ionbot/PXD010138/ionbot_files/160929_Br203_R1', '/home/robbe/ionbot/PXD010138/ionbot_files/160922_BL333-3_R2', '/home/robbe/ionbot/PXD010138/ionbot_files/161007_C152-3_R2', '/home/robbe/ionbot/PXD010138/ionbot_files/160929_Br203_R3', '/home/robbe/ionbot/PXD010138/ionbot_files/161206_A518_R1', '/home/robbe/ionbot/PXD010138/ionbot_files/161013_A420_R3', '/home/robbe/ionbot/PXD010138/ionbot_files/161206_A948_R3', '/home/robbe/ionbot/PXD010138/ionbot_files/170317_B215_R5', '/home/robbe/ionbot
# ...
