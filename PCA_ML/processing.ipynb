# %%
import pandas as pd
import sys
sys.path.insert(1, "/home/robbe/ionbot")
import OxiAnalysis as OA

# %%
PXD014381 = pd.read_csv("/home/robbe/ionbot/ionbot_0.9.5/PXD014381/mzml_files/QuantifiedPeptides.tsv", sep="\t")
PXD015122 = pd.read_csv("/home/robbe/ionbot/ionbot_0.9.5/PXD015122/mzml_files/QuantifiedPeptides.tsv", sep="\t")
PXD012477 = pd.read_csv("/home/robbe/ionbot/ionbot_0.9.5/PXD012477/flashlfq_results/QuantifiedPeptides.tsv", sep="\t")
PXD016278 = pd.read_csv("/home/robbe/ionbot/ionbot_0.9.5/PXD016278/flashlfq/QuantifiedPeptides.tsv", sep="\t")
PXD018549 = pd.read_csv("/home/robbe/ionbot/ionbot_0.9.5/PXD018549/mzml_files/QuantifiedPeptides.tsv", sep="\t")
PXD022545 = pd.read_csv("/home/robbe/ionbot/ionbot_0.9.5/PXD022545/new_quatn/QuantifiedPeptides.tsv", sep="\t")
PXD008050 = pd.read_csv("/home/robbe/ionbot/ionbot_0.9.5/PXD008050/quant/QuantifiedPeptides.tsv", sep="\t")
PXD004010 = pd.read_csv("/home/robbe/ionbot/ionbot_0.9.5/PXD004010/quant/QuantifiedPeptides.tsv", sep="\t")
datalist = [PXD014381, PXD015122, PXD012477, PXD016278, PXD018549, PXD022545, PXD008050, PXD004010]

# %%
for i in datalist:
    cols = [col for col in i.columns if "Intensity" in col]
    OA.quantile_transform(i, cols)

# %%
from functools import reduce
import pandas as pd
data = reduce(lambda df_left, df_right: pd.merge(df_left, df_right, how="outer", on="Sequence"), datalist)
# Out:
# /tmp/ipykernel_2863224/754067759.py:3: FutureWarning: Passing 'suffixes' which cause duplicate columns {'Protein Groups_x', 'Organism_x', 'Base Sequence_x', 'Gene Names_x'} in the result is deprecated and will raise a MergeError in a future version.
#   data = reduce(lambda df_left, df_right: pd.merge(df_left, df_right, how="outer", on="Sequence"), datalist)
# /tmp/ipykernel_2863224/754067759.py:3: FutureWarning: Passing 'suffixes' which cause duplicate columns {'Protein Groups_x', 'Organism_x', 'Base Sequence_x', 'Gene Names_x'} in the result is deprecated and will raise a MergeError in a future version.
#   data = reduce(lambda df_left, df_right: pd.merge(df_left, df_right, how="outer", on="Sequence"), datalist)
# /tmp/ipykernel_2863224/754067759.py:3: FutureWarning: Passing 'suffixes' which cause duplicate columns {'Protein Groups_x', 'Organism_x', 'Base Sequence_x', 'Gene Names_x'} in the result is deprecated and will raise a MergeError in a future version.
#   data = reduce(lambda df_left, df_right: pd.merge(df_left, df_right, how="outer", on="Sequence"), datalist)

# %%
datafiltered = data.filter(regex=r"Intensity*|Sequence")

# %%
datafiltered.head()
# Out:
#                                             Sequence  \
# 0  AAAAAAAAAAAAAAAAGATCLER20|[935]Atto495Maleimid...
# 1                AAAAAAAAAAGAAGGR0|[1]Acetyl[N-TERM]
# 2                                    AAAAAAAAAVSRnan
# 3  AAAAAAAAVPSAGPAGPAPTSAAGR0|[9999530]Methyl_2H(...
# 4                       AAAAAAAAVPSAGPAGPAPTSAAGRnan
#
#              Base Sequence_x  Intensity_QX01983  \
# 0    AAAAAAAAAAAAAAAAGATCLER                NaN
# 1           AAAAAAAAAAGAAGGR                NaN
# 2               AAAAAAAAAVSR                NaN
# 3  AAAAAAAAVPSAGPAGPAPTSAAGR           4.581408
# 4  AAAAAAAAVPSAGPAGPAPTSAAGR           5.150464
#
#    Intensity_QX01981_160316090220  Intensity_QX01867  Intensity_QX01870  \
# 0                             NaN                NaN                NaN
# 1                             NaN           6.104019           5.824088
# 2                             NaN                NaN                NaN
# 3                        4.448109           4.471945           4.108372
# 4                        4.999083           5.230175           5.288675
#
#    Intensity_QX01873  Intensity_QX01862  Intensity_QX01865  Intensity_QX01868  \
# 0                NaN                NaN                NaN                NaN
# 1           5.510077           5.965650           6.001785           5.811058
# 2                NaN           4.250094                NaN                NaN
# 3           4.305622           4.296744           4.882412           4.691012
# 4           5.551720           5.231277           5.263707           5.260511
#
#    ...  Intensity_ad_pl01  Intensity_ad_pl08  Intensity_ad_pl09  \
# 0  ...                NaN                NaN                NaN
# 1  ...                NaN                NaN                NaN
# 2  ...                NaN                NaN                NaN
# 3  ...                NaN                NaN                NaN
# 4  ...                NaN                NaN                NaN
#
#    Intensity_ad_pl10  Intensity_ad_pl04  Intensity_ad_pl02  Intensity_ad_pl05  \
# 0                NaN                NaN                NaN                NaN
# 1                NaN                NaN                NaN                NaN
# 2                NaN                NaN                NaN                NaN
# 3                NaN                NaN                NaN                NaN
# 4                NaN                NaN           5.011104                NaN
#
#   Intensity_ad_pl06  Intensity_ad_pl07  Intensity_ad_pl03
# 0               NaN                NaN                NaN
# 1               NaN                NaN                NaN
# 2               NaN                NaN                NaN
# 3               NaN                NaN                NaN
# 4               NaN                NaN                NaN
#
# [5 rows x 650 columns]

# %%
datafiltered.loc["Total"] = datafiltered.sum()
# Out:
# /tmp/ipykernel_2863224/2442782494.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   datafiltered.loc["Total"] = datafiltered.sum()
# /tmp/ipykernel_2863224/2442782494.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datafiltered.loc["Total"] = datafiltered.sum()

# %%
Totals = datafiltered.loc["Total"]

# %%
data2 = datafiltered.drop(datafiltered.index[-1], axis=0)

# %%
data2.drop(list(data2.filter(regex = 'Base|Modifications')), axis = 1, inplace = True)

# %%
data2
# Out:
#                                                  Sequence  Intensity_QX01983  \
# 0       AAAAAAAAAAAAAAAAGATCLER20|[935]Atto495Maleimid...                NaN
# 1                     AAAAAAAAAAGAAGGR0|[1]Acetyl[N-TERM]                NaN
# 2                                         AAAAAAAAAVSRnan                NaN
# 3       AAAAAAAAVPSAGPAGPAPTSAAGR0|[9999530]Methyl_2H(...           4.581408
# 4                            AAAAAAAAVPSAGPAGPAPTSAAGRnan           5.150464
# ...                                                   ...                ...
# 504046                                   YYWAAPEAYLGNKnan                NaN
# 504047  YYWGGQYTWDMAK11|[35]oxidation[M]|6|[7]Deamidat...                NaN
# 504048                                        YYYIPQYKnan                NaN
# 504049                                   YYYVPADFVEYEKnan                NaN
# 504050                               YYYWVINPADSSGITPKnan                NaN
#
#         Intensity_QX01981_160316090220  Intensity_QX01867  Intensity_QX01870  \
# 0                                  NaN                NaN                NaN
# 1                                  NaN           6.104019           5.824088
# 2                                  NaN                NaN                NaN
# 3                             4.448109           4.471945           4.108372
# 4                             4.999083           5.230175           5.288675
# ...                                ...                ...                ...
# 504046                             NaN                NaN                NaN
# 504047                             NaN                NaN                NaN
# 504048                             NaN                NaN                NaN
# 504049                             NaN                NaN                NaN
# 504050                             NaN                NaN                NaN
#
#         Intensity_QX01873  Intensity_QX01862  Intensity_QX01865  \
# 0                     NaN                NaN                NaN
# 1                5.510077           5.965650           6.001785
# 2                     NaN           4.250094                NaN
# 3                4.305622           4.296744           4.882412
# 4                5.551720           5.231277           5.263707
# ...                   ...                ...                ...
# 504046                NaN                NaN                NaN
# 504047                NaN                NaN                NaN
# 504048                NaN                NaN                NaN
# 504049                NaN                NaN                NaN
# 504050                NaN                NaN                NaN
#
#         Intensity_QX01868  Intensity_QX01984  ...  Intensity_ad_pl01  \
# 0                     NaN                NaN  ...                NaN
# 1                5.811058           5.306553  ...                NaN
# 2                     NaN                NaN  ...                NaN
# 3                4.691012           4.427366  ...                NaN
# 4                5.260511           4.933917  ...                NaN
# ...                   ...                ...  ...                ...
# 504046                NaN                NaN  ...                NaN
# 504047                NaN                NaN  ...                NaN
# 504048                NaN                NaN  ...                NaN
# 504049                NaN                NaN  ...                NaN
# 504050                NaN                NaN  ...                NaN
#
#         Intensity_ad_pl08  Intensity_ad_pl09  Intensity_ad_pl10  \
# 0                     NaN                NaN                NaN
# 1                     NaN                NaN                NaN
# 2                     NaN                NaN                NaN
# 3                     NaN                NaN                NaN
# 4                     NaN                NaN                NaN
# ...                   ...                ...                ...
# 504046                NaN                NaN                NaN
# 504047                NaN                NaN                NaN
# 504048                NaN           6.334195                NaN
# 504049                NaN                NaN           4.356755
# 504050                NaN                NaN                NaN
#
#         Intensity_ad_pl04  Intensity_ad_pl02  Intensity_ad_pl05  \
# 0                     NaN                NaN                NaN
# 1                     NaN                NaN                NaN
# 2                     NaN                NaN                NaN
# 3                     NaN                NaN                NaN
# 4                     NaN           5.011104                NaN
# ...                   ...                ...                ...
# 504046                NaN           5.138923                NaN
# 504047                NaN                NaN                NaN
# 504048                NaN           4.130612                NaN
# 504049                NaN                NaN                NaN
# 504050           3.190956                NaN                NaN
#
#         Intensity_ad_pl06  Intensity_ad_pl07  Intensity_ad_pl03
# 0                     NaN                NaN                NaN
# 1                     NaN                NaN                NaN
# 2                     NaN                NaN                NaN
# 3                     NaN                NaN                NaN
# 4                     NaN                NaN                NaN
# ...                   ...                ...                ...
# 504046                NaN                NaN                NaN
# 504047                NaN                NaN                NaN
# 504048                NaN                NaN                NaN
# 504049           6.015365           3.883401                NaN
# 504050                NaN                NaN                NaN
#
# [504051 rows x 642 columns]

# %%
data3 = OA.summedintensities(data2)
# Out:
# /home/robbe/ionbot/OxiAnalysis.py:442: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   quantexox.drop(list(quantexox.filter(regex = 'Detection Type')), axis = 1, inplace = True)

# %%
data3
# Out:
#                      Modifications  Intensity_QX01983  \
# 0        [1384]Homocysteic_acid[M]           0.000000
# 1              [1914]Met->AspSA[M]          13.458177
# 2         [1915]Decarboxylation[D]           5.280874
# 3         [1915]Decarboxylation[E]          26.260401
# 4            [1916]Aspartylurea[H]           0.000000
# ..                             ...                ...
# 85  [743]4-ONE+Delta:H(-2)O(-1)[K]           0.000000
# 86                    [860]G-H1[R]           0.000000
# 87            [936]Chlorination[Y]           3.945998
# 88          [937]dichlorination[Y]           0.000000
# 89        [949]3-deoxyglucosone[R]          22.386301
#
#     Intensity_QX01981_160316090220  Intensity_QX01867  Intensity_QX01870  \
# 0                         0.000000           0.000000           0.000000
# 1                        18.110081          19.705196          18.747091
# 2                         5.328221           5.728828           5.539504
# 3                        11.628970          16.346294          15.304845
# 4                         0.000000           0.000000           0.000000
# ..                             ...                ...                ...
# 85                        0.000000           0.000000           0.000000
# 86                        0.000000           0.000000           0.000000
# 87                        3.478483           3.671564           3.792013
# 88                        0.000000           0.000000           0.000000
# 89                       16.421765          13.024073          18.717500
#
#     Intensity_QX01873  Intensity_QX01862  Intensity_QX01865  \
# 0            0.000000           0.000000           0.000000
# 1            0.000000          15.263346           9.519258
# 2            5.178346           5.834690          10.677683
# 3           16.466727          26.341687          20.847103
# 4            0.000000           0.000000           0.000000
# ..                ...                ...                ...
# 85           0.000000           0.000000           0.000000
# 86           0.000000           0.000000           0.000000
# 87           3.421372           3.966632           4.082862
# 88           0.000000           0.000000           0.000000
# 89          23.596841          13.011140          18.284020
#
#     Intensity_QX01868  Intensity_QX01984  ...  Intensity_ad_pl08  \
# 0            0.000000           0.000000  ...          23.808069
# 1           15.117092          19.134427  ...          67.069341
# 2           10.708628           5.378035  ...          19.275377
# 3           22.863306          20.264301  ...          10.560834
# 4            0.000000           0.000000  ...           9.310413
# ..                ...                ...  ...                ...
# 85           0.000000           0.000000  ...           0.000000
# 86           0.000000           0.000000  ...           0.000000
# 87           0.000000           3.278947  ...           0.000000
# 88           0.000000           0.000000  ...           0.000000
# 89          18.589535          18.053328  ...           0.000000
#
#     Intensity_ad_pl09  Intensity_ad_pl10  Intensity_ad_pl04  \
# 0            5.042582           0.000000           0.000000
# 1           44.810078          47.195714          89.912161
# 2           20.953505          15.569565          15.211714
# 3           36.647692          20.396514          18.556137
# 4            4.083227           0.000000           0.000000
# ..                ...                ...                ...
# 85           0.000000           0.000000           0.000000
# 86           0.000000           0.000000           0.000000
# 87           0.000000           3.421376           0.000000
# 88           0.000000           0.000000           8.122204
# 89           0.000000           0.000000           0.000000
#
#     Intensity_ad_pl02  Intensity_ad_pl05  Intensity_ad_pl06  \
# 0           10.285592           4.678117          10.436478
# 1           86.847318          64.964258          67.469439
# 2           14.215881           5.271097           5.064204
# 3           17.704149          28.637163           5.694045
# 4            0.000000           3.430715           9.802465
# ..                ...                ...                ...
# 85           0.000000           0.000000           0.000000
# 86           0.000000           0.000000           0.000000
# 87           0.000000           4.011537           4.238272
# 88           0.000000           4.933519           0.000000
# 89           0.000000           0.000000           0.000000
#
#     Intensity_ad_pl07  Intensity_ad_pl03  Oxmod?
# 0           10.172032          16.815052     265
# 1           58.836618          74.677359     439
# 2            3.560350           3.928794     329
# 3           28.543951          18.936602     478
# 4            4.920936           4.272493     172
# ..                ...                ...     ...
# 85           0.000000           0.000000      18
# 86           0.000000           0.000000      74
# 87           3.547196           0.000000     236
# 88           0.000000           0.000000      56
# 89           0.000000           0.000000      54
#
# [90 rows x 643 columns]

# %%
data3.drop("Oxmod?",axis=1, inplace=True)

# %%
data4 = data3.T

# %%
data4 = data4.rename(columns=data4.iloc[0])

# %%
data4 = data4.drop(data4.index[0])

# %%
data4
# Out:
#                                [1384]Homocysteic_acid[M] [1914]Met->AspSA[M]  \
# Intensity_QX01983                                    0.0           13.458177
# Intensity_QX01981_160316090220                       0.0           18.110081
# Intensity_QX01867                                    0.0           19.705196
# Intensity_QX01870                                    0.0           18.747091
# Intensity_QX01873                                    0.0                 0.0
# ...                                                  ...                 ...
# Intensity_ad_pl02                              10.285592           86.847318
# Intensity_ad_pl05                               4.678117           64.964258
# Intensity_ad_pl06                              10.436478           67.469439
# Intensity_ad_pl07                              10.172032           58.836618
# Intensity_ad_pl03                              16.815052           74.677359
#
#                                [1915]Decarboxylation[D]  \
# Intensity_QX01983                              5.280874
# Intensity_QX01981_160316090220                 5.328221
# Intensity_QX01867                              5.728828
# Intensity_QX01870                              5.539504
# Intensity_QX01873                              5.178346
# ...                                                 ...
# Intensity_ad_pl02                             14.215881
# Intensity_ad_pl05                              5.271097
# Intensity_ad_pl06                              5.064204
# Intensity_ad_pl07                               3.56035
# Intensity_ad_pl03                              3.928794
#
#                                [1915]Decarboxylation[E] [1916]Aspartylurea[H]  \
# Intensity_QX01983                             26.260401                   0.0
# Intensity_QX01981_160316090220                 11.62897                   0.0
# Intensity_QX01867                             16.346294                   0.0
# Intensity_QX01870                             15.304845                   0.0
# Intensity_QX01873                             16.466727                   0.0
# ...                                                 ...                   ...
# Intensity_ad_pl02                             17.704149                   0.0
# Intensity_ad_pl05                             28.637163              3.430715
# Intensity_ad_pl06                              5.694045              9.802465
# Intensity_ad_pl07                             28.543951              4.920936
# Intensity_ad_pl03                             18.936602              4.272493
#
#                                [1917]Formylasparagine[H] [1918]Carbonyl[A]  \
# Intensity_QX01983                                    0.0         10.181598
# Intensity_QX01981_160316090220                       0.0         10.456664
# Intensity_QX01867                               4.575844         10.996926
# Intensity_QX01870                               4.687361         10.997153
# Intensity_QX01873                               4.358819         10.914639
# ...                                                  ...               ...
# Intensity_ad_pl02                                    0.0         30.379551
# Intensity_ad_pl05                              14.896325         19.317212
# Intensity_ad_pl06                                    0.0         15.180385
# Intensity_ad_pl07                               5.379857         40.836548
# Intensity_ad_pl03                               9.120906          32.38856
#
#                                [1918]Carbonyl[E] [1918]Carbonyl[I]  \
# Intensity_QX01983                      16.874409          4.226018
# Intensity_QX01981_160316090220         15.938097          4.506698
# Intensity_QX01867                      14.190249          6.000948
# Intensity_QX01870                      16.575318          4.875357
# Intensity_QX01873                      17.267057               0.0
# ...                                          ...               ...
# Intensity_ad_pl02                       4.656882         58.061336
# Intensity_ad_pl05                      19.066566         46.246521
# Intensity_ad_pl06                      20.448703         31.760997
# Intensity_ad_pl07                       22.05287         69.592587
# Intensity_ad_pl03                      10.116255         75.214327
#
#                                [1918]Carbonyl[Q]  ... [721]4-ONE[C]  \
# Intensity_QX01983                       4.277008  ...           0.0
# Intensity_QX01981_160316090220          4.716808  ...           0.0
# Intensity_QX01867                       5.044739  ...           0.0
# Intensity_QX01870                       4.866679  ...           0.0
# Intensity_QX01873                       4.512607  ...           0.0
# ...                                          ...  ...           ...
# Intensity_ad_pl02                       29.14093  ...      4.659691
# Intensity_ad_pl05                      10.409982  ...           0.0
# Intensity_ad_pl06                       4.761232  ...           0.0
# Intensity_ad_pl07                      25.461924  ...      4.479478
# Intensity_ad_pl03                      24.982152  ...      4.398261
#
#                                [721]4-ONE[H] [721]4-ONE[K]  \
# Intensity_QX01983                        0.0           0.0
# Intensity_QX01981_160316090220           0.0           0.0
# Intensity_QX01867                        0.0           0.0
# Intensity_QX01870                        0.0           0.0
# Intensity_QX01873                        0.0           0.0
# ...                                      ...           ...
# Intensity_ad_pl02                        0.0           0.0
# Intensity_ad_pl05                        0.0           0.0
# Intensity_ad_pl06                        0.0           0.0
# Intensity_ad_pl07                        0.0           0.0
# Intensity_ad_pl03                        0.0           0.0
#
#                                [743]4-ONE+Delta:H(-2)O(-1)[C]  \
# Intensity_QX01983                                         0.0
# Intensity_QX01981_160316090220                            0.0
# Intensity_QX01867                                         0.0
# Intensity_QX01870                                         0.0
# Intensity_QX01873                                         0.0
# ...                                                       ...
# Intensity_ad_pl02                                         0.0
# Intensity_ad_pl05                                         0.0
# Intensity_ad_pl06                                    5.354259
# Intensity_ad_pl07                                         0.0
# Intensity_ad_pl03                                         0.0
#
#                                [743]4-ONE+Delta:H(-2)O(-1)[H]  \
# Intensity_QX01983                                         0.0
# Intensity_QX01981_160316090220                            0.0
# Intensity_QX01867                                         0.0
# Intensity_QX01870                                         0.0
# Intensity_QX01873                                         0.0
# ...                                                       ...
# Intensity_ad_pl02                                         0.0
# Intensity_ad_pl05                                         0.0
# Intensity_ad_pl06                                    4.698495
# Intensity_ad_pl07                                         0.0
# Intensity_ad_pl03                                         0.0
#
#                                [743]4-ONE+Delta:H(-2)O(-1)[K] [860]G-H1[R]  \
# Intensity_QX01983                                         0.0          0.0
# Intensity_QX01981_160316090220                            0.0          0.0
# Intensity_QX01867                                         0.0          0.0
# Intensity_QX01870                                         0.0          0.0
# Intensity_QX01873                                         0.0          0.0
# ...                                                       ...          ...
# Intensity_ad_pl02                                         0.0          0.0
# Intensity_ad_pl05                                         0.0          0.0
# Intensity_ad_pl06                                         0.0          0.0
# Intensity_ad_pl07                                         0.0          0.0
# Intensity_ad_pl03                                         0.0          0.0
#
#                                [936]Chlorination[Y] [937]dichlorination[Y]  \
# Intensity_QX01983                          3.945998                    0.0
# Intensity_QX01981_160316090220             3.478483                    0.0
# Intensity_QX01867                          3.671564                    0.0
# Intensity_QX01870                          3.792013                    0.0
# Intensity_QX01873                          3.421372                    0.0
# ...                                             ...                    ...
# Intensity_ad_pl02                               0.0                    0.0
# Intensity_ad_pl05                          4.011537               4.933519
# Intensity_ad_pl06                          4.238272                    0.0
# Intensity_ad_pl07                          3.547196                    0.0
# Intensity_ad_pl03                               0.0                    0.0
#
#                                [949]3-deoxyglucosone[R]
# Intensity_QX01983                             22.386301
# Intensity_QX01981_160316090220                16.421765
# Intensity_QX01867                             13.024073
# Intensity_QX01870                               18.7175
# Intensity_QX01873                             23.596841
# ...                                                 ...
# Intensity_ad_pl02                                   0.0
# Intensity_ad_pl05                                   0.0
# Intensity_ad_pl06                                   0.0
# Intensity_ad_pl07                                   0.0
# Intensity_ad_pl03                                   0.0
#
# [641 rows x 90 columns]

# %%
Totals
# Out:
# Sequence                          AAAAAAAAAAAAAAAAGATCLER20|[935]Atto495Maleimid...
# Base Sequence_x                                                                 NaN
# Intensity_QX01983                                                     124748.962236
# Intensity_QX01981_160316090220                                        125237.443954
# Intensity_QX01867                                                     127404.536105
#                                                         ...
# Intensity_ad_pl02                                                      89247.814631
# Intensity_ad_pl05                                                      83349.677571
# Intensity_ad_pl06                                                      83616.970664
# Intensity_ad_pl07                                                      82748.325227
# Intensity_ad_pl03                                                      89302.567943
# Name: Total, Length: 650, dtype: object

# %%
Totals = Totals.drop(["Sequence","Base Sequence_x", "Base Sequence_y"])

# %%
data5 = data4.div(Totals, axis=0)

# %%
data5.to_csv("data.csv")
